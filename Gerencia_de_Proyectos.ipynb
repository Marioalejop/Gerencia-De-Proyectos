# %% [markdown]
# <a href="https://colab.research.google.com/github/Marioalejop/Gerencia-De-Proyectos/blob/main/Gerencia_de_Proyectos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Herramientas para procesar datos, suceptible a demandas legales. Las máquinas no pueden saber si es legal o no. Somos nosotros los ingenieros los que tomamos las decisiones. Automatizaaciones.
# Progamar sesiones estructuradas. Evitar las reuniones con las metodologias ágiles no garantixa una buena productividad.

# %% [markdown]
# ##PMBOK v8
#
# Portada moderna.
#
# 48.000 puntos, ciencia de datos aplicada a la gestión de proyectos.
#
# 6 Principios
#
# Ajustar el enfoque de gestión al entreno, escala y caracteristicas de un proyecto.
#
# El arte de la Sastería (Tailoring)
# * Seleccionar: metodologias agiles.
#
# * Organización.
# * Proyecto.
# * Mejora continua.
#
# Liderar con valor, respaldar las decisiones con matematicas precisas (EVM).
# * CPI
# * SPI
# * EAC
# * TCPI - equilibrio
#
# Informe final, Retrospectiva,
# Lecciones.

# %% [markdown]
# <a href="https://colab.research.google.com/github/Marioalejop/Gerencia-De-Proyectos/blob/main/Sesion10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Resumen Video "Ruta Crítica y Compresión"

# %% [markdown]
# 1. Red Lógica
# Introduce el diagrama de red del proyecto: cómo las actividades se conectan mostrando divergencia y convergencia de rutas lógicas (mapear las "piezas del rompecabezas" del proyecto).
#
# 2. La Ruta Crítica
# Define el concepto central: la ruta crítica es la secuencia de actividades que representa el camino más largo de la red y determina la duración mínima del proyecto. Explica el cálculo mediante:
# * Pase hacia adelante (Forward Pass): calcula inicio y finalización tempranos.
# * Pase hacia atrás (Backward Pass): calcula inicio y finalización tardíos.
# El objetivo es cumplir la fecha límite del proyecto sin forzar ni arruinar el cronograma.
#
# 3. Holguras y Retraso (Costo del tiempo)
#
# * Holgura total: tiempo que una actividad puede retrasarse sin afectar la fecha de fin del proyecto (en la ruta crítica, la holgura es cero → "zero flexibility").
# * Presenta un caso práctico: una fecha límite inamovible (20 de noviembre 2024) que el cálculo inicial excede.
# * Costo de retraso: la reducción del ROI esperado cuando se retrasa una actividad de la ruta crítica.
#
# 4. Técnicas de Compresión
# Compara dos estrategias para acortar el cronograma:Intensificación (Crashing): inyectar más recursos → mayor costo, mismo riesgo.
# Aceleración (Fast-tracking): ejecutar actividades en paralelo → mismo costo, pero mayor riesgo y posible retrabajo.
# Se muestra una comparación visual (Normal / Tracking / Crashing) evidenciando el impacto en riesgo y costo de cada opción.
#
# 5. Cronograma Optimizado (Entregable final)
# Presenta el resultado: un diagrama de Gantt final con: Ruta crítica resaltada (holgura cero)
# Holguras visibles para optimización
# Hitos de lanzamiento alineados
# Plan de contingencia basado en riesgos
